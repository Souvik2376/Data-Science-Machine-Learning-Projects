# %% [markdown]
# # Horse Survival Prediction

# %% [markdown]
# ## Import Libraries

# %%
! pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.9.1.1-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\users\asus\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\asus\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.1.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import plotly.express as px
from wordcloud import WordCloud
from scipy import signal
import scipy
#to supress warning
import warnings
warnings.filterwarnings('ignore')


#to make shell more intractive
from IPython.display import display

# setting up the chart size and background
plt.rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv("horse.csv")

# %%
df.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
#    ... packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0  ...               45.0           8.4               NaN            NaN
# 1  ...               50.0          85.0            cloudy            2.0
# 2  ...               33.0           6.7               NaN            NaN
# 3  ...               48.0           7.2     serosanguious            5.3
# 4  ...               74.0           7.4               NaN            NaN
#
#       outcome  surgical_lesion lesion_1 lesion_2  lesion_3  cp_data
# 0        died               no    11300        0         0       no
# 1  euthanized               no     2208        0         0       no
# 2       lived               no        0        0         0      yes
# 3        died              yes     2208        0         0      yes
# 4        died               no     4300        0         0       no
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 294                cold              NaN   pale_cyanotic
# 295                cool        increased   pale_cyanotic
# 296                cold          reduced   pale_cyanotic
# 297                cool          reduced       pale_pink
# 298                 NaN              NaN             NaN
#
#     capillary_refill_time  ... packed_cell_volume total_protein  \
# 294            more_3_sec  ...               55.0          65.0
# 295            more_3_sec  ...               44.0           NaN
# 296            less_3_sec  ...               60.0           6.8
# 297            less_3_sec  ...               50.0           6.0
# 298                   NaN  ...               36.0          62.0
#
#     abdomo_appearance abdomo_protein     outcome  surgical_lesion lesion_1  \
# 294               NaN            NaN  euthanized               no     3205
# 295     serosanguious            3.3  euthanized              yes     2208
# 296               NaN            NaN        died              yes     3205
# 297     serosanguious            3.4       lived              yes     2208
# 298             clear            1.0  euthanized               no     6112
#
#     lesion_2  lesion_3  cp_data
# 294        0         0       no
# 295        0         0      yes
# 296        0         0       no
# 297        0         0      yes
# 298        0         0       no
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['surgery', 'age', 'hospital_number', 'rectal_temp', 'pulse',
#        'respiratory_rate', 'temp_of_extremities', 'peripheral_pulse',
#        'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis',
#        'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux',
#        'nasogastric_reflux_ph', 'rectal_exam_feces', 'abdomen',
#        'packed_cell_volume', 'total_protein', 'abdomo_appearance',
#        'abdomo_protein', 'outcome', 'surgical_lesion', 'lesion_1', 'lesion_2',
#        'lesion_3', 'cp_data'],
#       dtype='object')

# %%
df.shape
# Out:
# (299, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    object
#  1   age                    299 non-null    object
#  2   hospital_number        299 non-null    int64
#  3   rectal_temp            239 non-null    float64
#  4   pulse                  275 non-null    float64
#  5   respiratory_rate       241 non-null    float64
#  6   temp_of_extremities    243 non-null    object
#  7   peripheral_pulse       230 non-null    object
#  8   mucous_membrane        252 non-null    object
#  9   capillary_refill_time  267 non-null    object
#  10  pain                   244 non-null    object
#  11  peristalsis            255 non-null    object
#  12  abdominal_distention   243 non-null    object
#  13  nasogastric_tube       195 non-null    object
#  14  nasogastric_reflux     193 non-null    object
#  15  nasogastric_reflux_ph  53 non-null     float64
#  16  rectal_exam_feces      197 non-null    object
#  17  abdomen                181 non-null    object
#  18  packed_cell_volume     270 non-null    float64
#  19  total_protein          266 non-null    float64
#  20  abdomo_appearance      134 non-null    object
#  21  abdomo_protein         101 non-null    float64
#  22  outcome                299 non-null    object
#  23  surgical_lesion        299 non-null    object
#  24  lesion_1               299 non-null    int64
#  25  lesion_2               299 non-null    int64
#  26  lesion_3               299 non-null    int64
#  27  cp_data                299 non-null    object
# dtypes: float64(7), int64(4), object(17)
# memory usage: 65.5+ KB

# %%
df.corr().style.background_gradient(cmap = 'Greys')
# Out:
# <style type="text/css">
# #T_7c202_row0_col0, #T_7c202_row1_col1, #T_7c202_row2_col2, #T_7c202_row3_col3, #T_7c202_row4_col4, #T_7c202_row4_col9, #T_7c202_row4_col10, #T_7c202_row5_col5, #T_7c202_row6_col6, #T_7c202_row7_col7, #T_7c202_row8_col8, #T_7c202_row9_col4, #T_7c202_row9_col9, #T_7c202_row10_col4, #T_7c202_row10_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7c202_row0_col1, #T_7c202_row3_col5 {
#   background-color: #e4e4e4;
#   color: #000000;
# }
# #T_7c202_row0_col2 {
#   background-color: #adadad;
#   color: #000000;
# }
# #T_7c202_row0_col3 {
#   background-color: #c6c6c6;
#   color: #000000;
# }
# #T_7c202_row0_col4 {
#   background-color: #b0b0b0;
#   color: #000000;
# }
# #T_7c202_row0_col5, #T_7c202_row5_col10 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_7c202_row0_col6 {
#   background-color: #d2d2d2;
#   color: #000000;
# }
# #T_7c202_row0_col7, #T_7c202_row3_col1, #T_7c202_row3_col8, #T_7c202_row8_col6 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_7c202_row0_col8, #T_7c202_row4_col1, #T_7c202_row10_col7 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_7c202_row0_col9, #T_7c202_row4_col2, #T_7c202_row10_col1 {
#   background-color: #f5f5f5;
#   color: #000000;
# }
# #T_7c202_row0_col10, #T_7c202_row1_col9, #T_7c202_row9_col2 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_7c202_row1_col0, #T_7c202_row8_col0 {
#   background-color: #cdcdcd;
#   color: #000000;
# }
# #T_7c202_row1_col2 {
#   background-color: #d3d3d3;
#   color: #000000;
# }
# #T_7c202_row1_col3 {
#   background-color: #c7c7c7;
#   color: #000000;
# }
# #T_7c202_row1_col4, #T_7c202_row9_col6 {
#   background-color: #888888;
#   color: #f1f1f1;
# }
# #T_7c202_row1_col5, #T_7c202_row10_col2 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_7c202_row1_col6 {
#   background-color: #bbbbbb;
#   color: #000000;
# }
# #T_7c202_row1_col7 {
#   background-color: #c4c4c4;
#   color: #000000;
# }
# #T_7c202_row1_col8 {
#   background-color: #e1e1e1;
#   color: #000000;
# }
# #T_7c202_row1_col10, #T_7c202_row3_col9, #T_7c202_row5_col1, #T_7c202_row7_col6, #T_7c202_row8_col1 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_7c202_row2_col0 {
#   background-color: #989898;
#   color: #f1f1f1;
# }
# #T_7c202_row2_col1 {
#   background-color: #d6d6d6;
#   color: #000000;
# }
# #T_7c202_row2_col3 {
#   background-color: #929292;
#   color: #f1f1f1;
# }
# #T_7c202_row2_col4 {
#   background-color: #afafaf;
#   color: #000000;
# }
# #T_7c202_row2_col5 {
#   background-color: #9e9e9e;
#   color: #f1f1f1;
# }
# #T_7c202_row2_col6 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_7c202_row2_col7 {
#   background-color: #c2c2c2;
#   color: #000000;
# }
# #T_7c202_row2_col8, #T_7c202_row10_col3 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_7c202_row2_col9 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_7c202_row2_col10 {
#   background-color: #e5e5e5;
#   color: #000000;
# }
# #T_7c202_row3_col0 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_7c202_row3_col2 {
#   background-color: #939393;
#   color: #f1f1f1;
# }
# #T_7c202_row3_col4 {
#   background-color: #999999;
#   color: #f1f1f1;
# }
# #T_7c202_row3_col6, #T_7c202_row10_col9 {
#   background-color: #bfbfbf;
#   color: #000000;
# }
# #T_7c202_row3_col7 {
#   background-color: #d0d0d0;
#   color: #000000;
# }
# #T_7c202_row3_col10 {
#   background-color: #dedede;
#   color: #000000;
# }
# #T_7c202_row4_col0 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_7c202_row4_col3 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_7c202_row4_col5, #T_7c202_row4_col6, #T_7c202_row6_col0, #T_7c202_row6_col1, #T_7c202_row6_col2, #T_7c202_row6_col3, #T_7c202_row6_col4, #T_7c202_row6_col7, #T_7c202_row6_col8, #T_7c202_row7_col9, #T_7c202_row7_col10, #T_7c202_row9_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_7c202_row4_col7 {
#   background-color: #606060;
#   color: #f1f1f1;
# }
# #T_7c202_row4_col8 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_7c202_row5_col0 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_7c202_row5_col2 {
#   background-color: #a5a5a5;
#   color: #f1f1f1;
# }
# #T_7c202_row5_col3 {
#   background-color: #e9e9e9;
#   color: #000000;
# }
# #T_7c202_row5_col4, #T_7c202_row9_col10 {
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_7c202_row5_col6 {
#   background-color: #b9b9b9;
#   color: #000000;
# }
# #T_7c202_row5_col7 {
#   background-color: #a8a8a8;
#   color: #f1f1f1;
# }
# #T_7c202_row5_col8 {
#   background-color: #f4f4f4;
#   color: #000000;
# }
# #T_7c202_row5_col9, #T_7c202_row6_col5, #T_7c202_row7_col1, #T_7c202_row9_col3 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# #T_7c202_row6_col9 {
#   background-color: #c8c8c8;
#   color: #000000;
# }
# #T_7c202_row6_col10, #T_7c202_row8_col2 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_7c202_row7_col0, #T_7c202_row9_col0 {
#   background-color: #ececec;
#   color: #000000;
# }
# #T_7c202_row7_col2, #T_7c202_row8_col10 {
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_7c202_row7_col3 {
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_7c202_row7_col4 {
#   background-color: #565656;
#   color: #f1f1f1;
# }
# #T_7c202_row7_col5 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_7c202_row7_col8 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_7c202_row8_col3 {
#   background-color: #dadada;
#   color: #000000;
# }
# #T_7c202_row8_col4 {
#   background-color: #9f9f9f;
#   color: #f1f1f1;
# }
# #T_7c202_row8_col5, #T_7c202_row10_col5 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_7c202_row8_col7 {
#   background-color: #cacaca;
#   color: #000000;
# }
# #T_7c202_row8_col9 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_7c202_row9_col5 {
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_7c202_row9_col7 {
#   background-color: #dbdbdb;
#   color: #000000;
# }
# #T_7c202_row9_col8, #T_7c202_row10_col8 {
#   background-color: #eaeaea;
#   color: #000000;
# }
# #T_7c202_row10_col0 {
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_7c202_row10_col6 {
#   background-color: #a4a4a4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c202">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c202_level0_col0" class="col_heading level0 col0" >hospital_number</th>
#       <th id="T_7c202_level0_col1" class="col_heading level0 col1" >rectal_temp</th>
#       <th id="T_7c202_level0_col2" class="col_heading level0 col2" >pulse</th>
#       <th id="T_7c202_level0_col3" class="col_heading level0 col3" >respiratory_rate</th>
#       <th id="T_7c202_level0_col4" class="col_heading level0 col4" >nasogastric_reflux_ph</th>
#       <th id="T_7c202_level0_col5" class="col_heading level0 col5" >packed_cell_volume</th>
#       <th id="T_7c202_level0_col6" class="col_heading level0 col6" >total_protein</th>
#       <th id="T_7c202_level0_col7" class="col_heading level0 col7" >abdomo_protein</th>
#       <th id="T_7c202_level0_col8" class="col_heading level0 col8" >lesion_1</th>
#       <th id="T_7c202_level0_col9" class="col_heading level0 col9" >lesion_2</th>
#       <th id="T_7c202_level0_col10" class="col_heading level0 col10" >lesion_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c202_level0_row0" class="row_heading level0 row0" >hospital_number</th>
#       <td id="T_7c202_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7c202_row0_col1" class="data row0 col1" >0.144118</td>
#       <td id="T_7c202_row0_col2" class="data row0 col2" >0.379607</td>
#       <td id="T_7c202_row0_col3" class="data row0 col3" >0.273350</td>
#       <td id="T_7c202_row0_col4" class="data row0 col4" >-0.005577</td>
#       <td id="T_7c202_row0_col5" class="data row0 col5" >-0.093508</td>
#       <td id="T_7c202_row0_col6" class="data row0 col6" >-0.228843</td>
#       <td id="T_7c202_row0_col7" class="data row0 col7" >-0.044184</td>
#       <td id="T_7c202_row0_col8" class="data row0 col8" >0.145397</td>
#       <td id="T_7c202_row0_col9" class="data row0 col9" >-0.050433</td>
#       <td id="T_7c202_row0_col10" class="data row0 col10" >-0.020950</td>
#     </tr>
#     <tr>
#       <th id="T_7c202_level0_row1" class="row_heading level0 row1" >rectal_temp</th>
#       <td id="T_7c202_row1_col0" class="data row1 col0" >0.144118</td>
#       <td id="T_7c202_row1_col1" class="data

# %%
df.describe().T.style.background_gradient(cmap = 'Greys')
# Out:
# <style type="text/css">
# #T_ebf56_row0_col0, #T_ebf56_row0_col1, #T_ebf56_row0_col2, #T_ebf56_row0_col3, #T_ebf56_row0_col4, #T_ebf56_row0_col5, #T_ebf56_row0_col6, #T_ebf56_row0_col7, #T_ebf56_row8_col0, #T_ebf56_row9_col0, #T_ebf56_row10_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ebf56_row1_col0 {
#   background-color: #505050;
#   color: #f1f1f1;
# }
# #T_ebf56_row1_col1, #T_ebf56_row1_col2, #T_ebf56_row1_col3, #T_ebf56_row1_col4, #T_ebf56_row1_col5, #T_ebf56_row1_col6, #T_ebf56_row1_col7, #T_ebf56_row2_col1, #T_ebf56_row2_col2, #T_ebf56_row2_col3, #T_ebf56_row2_col4, #T_ebf56_row2_col5, #T_ebf56_row2_col6, #T_ebf56_row2_col7, #T_ebf56_row3_col1, #T_ebf56_row3_col2, #T_ebf56_row3_col3, #T_ebf56_row3_col4, #T_ebf56_row3_col5, #T_ebf56_row3_col6, #T_ebf56_row3_col7, #T_ebf56_row4_col0, #T_ebf56_row4_col1, #T_ebf56_row4_col2, #T_ebf56_row4_col3, #T_ebf56_row4_col4, #T_ebf56_row4_col5, #T_ebf56_row4_col6, #T_ebf56_row4_col7, #T_ebf56_row5_col1, #T_ebf56_row5_col2, #T_ebf56_row5_col3, #T_ebf56_row5_col4, #T_ebf56_row5_col5, #T_ebf56_row5_col6, #T_ebf56_row5_col7, #T_ebf56_row6_col1, #T_ebf56_row6_col2, #T_ebf56_row6_col3, #T_ebf56_row6_col4, #T_ebf56_row6_col5, #T_ebf56_row6_col6, #T_ebf56_row6_col7, #T_ebf56_row7_col1, #T_ebf56_row7_col2, #T_ebf56_row7_col3, #T_ebf56_row7_col4, #T_ebf56_row7_col5, #T_ebf56_row7_col6, #T_ebf56_row7_col7, #T_ebf56_row8_col1, #T_ebf56_row8_col2, #T_ebf56_row8_col3, #T_ebf56_row8_col4, #T_ebf56_row8_col5, #T_ebf56_row8_col6, #T_ebf56_row8_col7, #T_ebf56_row9_col1, #T_ebf56_row9_col2, #T_ebf56_row9_col3, #T_ebf56_row9_col4, #T_ebf56_row9_col5, #T_ebf56_row9_col6, #T_ebf56_row9_col7, #T_ebf56_row10_col1, #T_ebf56_row10_col2, #T_ebf56_row10_col3, #T_ebf56_row10_col4, #T_ebf56_row10_col5, #T_ebf56_row10_col6, #T_ebf56_row10_col7 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ebf56_row2_col0 {
#   background-color: #1c1c1c;
#   color: #f1f1f1;
# }
# #T_ebf56_row3_col0 {
#   background-color: #4d4d4d;
#   color: #f1f1f1;
# }
# #T_ebf56_row5_col0 {
#   background-color: #232323;
#   color: #f1f1f1;
# }
# #T_ebf56_row6_col0 {
#   background-color: #282828;
#   color: #f1f1f1;
# }
# #T_ebf56_row7_col0 {
#   background-color: #e4e4e4;
#   color: #000000;
# }
# </style>
# <table id="T_ebf56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebf56_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_ebf56_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_ebf56_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_ebf56_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_ebf56_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_ebf56_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_ebf56_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_ebf56_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebf56_level0_row0" class="row_heading level0 row0" >hospital_number</th>
#       <td id="T_ebf56_row0_col0" class="data row0 col0" >299.000000</td>
#       <td id="T_ebf56_row0_col1" class="data row0 col1" >1087732.702341</td>
#       <td id="T_ebf56_row0_col2" class="data row0 col2" >1532031.581823</td>
#       <td id="T_ebf56_row0_col3" class="data row0 col3" >518476.000000</td>
#       <td id="T_ebf56_row0_col4" class="data row0 col4" >528904.000000</td>
#       <td id="T_ebf56_row0_col5" class="data row0 col5" >530301.000000</td>
#       <td id="T_ebf56_row0_col6" class="data row0 col6" >534736.000000</td>
#       <td id="T_ebf56_row0_col7" class="data row0 col7" >5305629.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebf56_level0_row1" class="row_heading level0 row1" >rectal_temp</th>
#       <td id="T_ebf56_row1_col0" class="data row1 col0" >239.000000</td>
#       <td id="T_ebf56_row1_col1" class="data row1 col1" >38.168619</td>
#       <td id="T_ebf56_row1_col2" class="data row1 col2" >0.733744</td>
#       <td id="T_ebf56_row1_col3" class="data row1 col3" >35.400000</td>
#       <td id="T_ebf56_row1_col4" class="data row1 col4" >37.800000</td>
#       <td id="T_ebf56_row1_col5" class="data row1 col5" >38.200000</td>
#       <td id="T_ebf56_row1_col6" class="data row1 col6" >38.500000</td>
#       <td id="T_ebf56_row1_col7" class="data row1 col7" >40.800000</td>
#     </tr>
#     <tr>
#       <th id="T_ebf56_level0_row2" class="row_heading level0 row2" >pulse</th>
#       <td id="T_ebf56_row2_col0" class="data row2 col0" >275.000000</td>
#       <td id="T_ebf56_row2_col1" class="data row2 col1" >72.000000</td>
#       <td id="T_ebf56_row2_col2" class="data row2 col2" >28.646219</td>
#       <td id="T_ebf56_row2_col3" class="data row2 col3" >30.000000</td>
#       <td id="T_ebf56_row2_col4" class="data row2 col4" >48.000000</td>
#       <td id="T_ebf56_row2_col5" class="data row2 col5" >64.000000</td>
#       <td id="T_ebf56_row2_col6" class="data row2 col6" >88.000000</td>
#       <td id="T_ebf56_row2_col7" class="data row2 col7" >184.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebf56_level0_row3" class="row_heading level0 row3" >respiratory_rate</th>
#       <td id="T_ebf56_row3_col0" class="data row3 col0" >241.000000</td>
#       <td id="T_ebf56_row3_col1" class="data row3 col1" >30.460581</td>
#       <td id="T_ebf56_row3_col2" class="data row3 col2" >17.666102</td>
#       <td id="T_ebf56_row3_col3" class="data row3 col3" >8.000000</td>
#       <td id="T_ebf56_row3_col4" class="data row3 col4" >18.000000</td>
#       <td id="T_ebf56_row3_col5" class="data row3 col5" >25.000000</td>
#       <td id="T_ebf56_row3_col6" class="data row3 col6" >36.000000</td>
#       <td id="T_ebf56_row3_col7" class="data row3 col7" >96.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebf56_level0_row4" class="row_heading level0 row4" >nasogastric_reflux_ph</th>
#       <td id="T_ebf56_row4_col0" class="data row4 col0" >53.000000</td>
#       <td id="T_ebf56_row4_col1" class="data row4 col1" >4.707547</td>
#       <td id="T_ebf56_row4_col2" class="data row4 col2" >1.982311</td>
#       <td id="T_ebf56_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_ebf56_row4_col4" class="data row4 col4" >3.000000</td>
#       <td id="T_ebf56_row4_col5" class="data row4 col5" >5.000000</td>
#       <td id="T_ebf56_row4_col6" class="data row4 col6" >6.500000</td>
#       <td id="T_ebf56_row4_col7" class="data row4 col7" >7.500000</td>
#     </tr>
#     <tr>
#       <th id="T_ebf56_level0_row5" class="row_heading level0 row5" >packed_cell_volume</th>
#       <td id="T_ebf56_row5_col0" class="data row5 col0" >270.000000</td>
#       <td id="T_ebf56_row5_col1" class="data row5 col1" >46.307407</td>
#       <td id="T_ebf56_row5_col2" class="data row5 col2" >10.436743</td>
#       <td id="T_ebf56_row5_col3" class="data row5 col3" >23.000000</td>
#       <td id="T_ebf56_row5_col4" class="data row5 col4" >38.000000</td>
#       <td id="T_ebf56_row5_col5" class="data row5 col5" >45.000000</td>
#       <td id="T_ebf56_row5_col6" class="data row5 col6" >52.000000</td>
#       <td id="T_ebf56_row5_col7" class="data row5 col7" >75.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebf56_level0_row6" class="row_heading level0 row6" >total_protein</th>
#       <td id="T_ebf56_row6_col0" class="data row6 col0" >266.000000</td>
#       <td id="T_ebf56_row6_col1" class="data row6 col1" >24.274436</td>
#       <td id="T_ebf56_row6_col2" class="data row6 col2" >27.364194</td>
#       <td id="T_ebf56_row6_col3" class="data row6 col3" >3.300000</td>
#       <td id="T_ebf56_row6_col4" class="data row6 col4" >6.500000</td>
#       <td id="T_ebf56_row6_col5" class="data row6 col5" >7.500000</td>
#       <td id="T_ebf56_row6_col6" class="data row6 col6" >56.750000</td>
#       <td id="T_ebf56_row6_col7" class="data row6 col7" >89.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ebf56_level0_row7" class="row_heading level0 row7" >abdomo_protein</th>
#       <td id="T_ebf56_row7_col0" class="data row7 col0" >101.000000</td>
#       <td id="T_ebf56_row7_col1" class="data row7 col1" >3.039604</td>
#       <td id="T_

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp               60
# pulse                     24
# respiratory_rate          58
# temp_of_extremities       56
# peripheral_pulse          69
# mucous_membrane           47
# capillary_refill_time     32
# pain                      55
# peristalsis               44
# abdominal_distention      56
# nasogastric_tube         104
# nasogastric_reflux       106
# nasogastric_reflux_ph    246
# rectal_exam_feces        102
# abdomen                  118
# packed_cell_volume        29
# total_protein             33
# abdomo_appearance        165
# abdomo_protein           198
# outcome                    0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#percentage of null each columns
for col in df.columns:
    print('{} :NUll %  :     {}'.format(col,df[col].isnull().sum()/df[col].count()))
# Out:
# surgery :NUll %  :     0.0
# age :NUll %  :     0.0
# hospital_number :NUll %  :     0.0
# rectal_temp :NUll %  :     0.2510460251046025
# pulse :NUll %  :     0.08727272727272728
# respiratory_rate :NUll %  :     0.24066390041493776
# temp_of_extremities :NUll %  :     0.23045267489711935
# peripheral_pulse :NUll %  :     0.3
# mucous_membrane :NUll %  :     0.1865079365079365
# capillary_refill_time :NUll %  :     0.1198501872659176
# pain :NUll %  :     0.22540983606557377
# peristalsis :NUll %  :     0.17254901960784313
# abdominal_distention :NUll %  :     0.23045267489711935
# nasogastric_tube :NUll %  :     0.5333333333333333
# nasogastric_reflux :NUll %  :     0.5492227979274611
# nasogastric_reflux_ph :NUll %  :     4.6415094339622645
# rectal_exam_feces :NUll %  :     0.5177664974619289
# abdomen :NUll %  :     0.6519337016574586
# packed_cell_volume :NUll %  :     0.10740740740740741
# total_protein :NUll %  :     0.12406015037593984
# abdomo_appearance :NUll %  :     1.2313432835820894
# abdomo_protein :NUll %  :     1.9603960396039604
# outcome :NUll %  :     0.0
# surgical_lesion :NUll %  :     0.0
# lesion_1 :NUll %  :     0.0
# lesion_2 :NUll %  :     0.0
# lesion_3 :NUll %  :     0.0
# cp_data :NUll %  :     0.0

# %% [markdown]
# ## Remove Null values

# %%
df.hospital_number.nunique()
# Out:
# 283

# %%
df.drop(['hospital_number'],axis=1,inplace=True)

# %%
sns.distplot(df['rectal_temp'])
# Out:
# <AxesSubplot:xlabel='rectal_temp', ylabel='Density'>

# %%
df['rectal_temp'].describe()
# Out:
# count    239.000000
# mean      38.168619
# std        0.733744
# min       35.400000
# 25%       37.800000
# 50%       38.200000
# 75%       38.500000
# max       40.800000
# Name: rectal_temp, dtype: float64

# %%
df['rectal_temp'] = df['rectal_temp'].fillna(df['rectal_temp'].mean())

# %%
sns.distplot(df['pulse'])
# Out:
# <AxesSubplot:xlabel='pulse', ylabel='Density'>

# %%
df['pulse'].describe()
# Out:
# count    275.000000
# mean      72.000000
# std       28.646219
# min       30.000000
# 25%       48.000000
# 50%       64.000000
# 75%       88.000000
# max      184.000000
# Name: pulse, dtype: float64

# %%
# Filling null values with mean of the numerical column
df['pulse'] = df['pulse'].fillna(df['pulse'].mean())
df['respiratory_rate'] = df['respiratory_rate'].fillna(df['respiratory_rate'].mean())
df['packed_cell_volume'] = df['packed_cell_volume'].fillna(df['packed_cell_volume'].mean())
df['total_protein'] = df['total_protein'].fillna(df['total_protein'].mean())

# %%
#drop
df.drop(['nasogastric_tube'],axis=1,inplace=True)
df.drop(['nasogastric_reflux'],axis=1,inplace=True)
df.drop(['nasogastric_reflux_ph'],axis=1,inplace=True)
df.drop(['rectal_exam_feces'],axis=1,inplace=True)
df.drop(['abdomen'],axis=1,inplace=True)
df.drop(['abdomo_protein'],axis=1,inplace=True)
df.drop(['abdomo_appearance'],axis=1,inplace=True)

# %%
df['temp_of_extremities'].value_counts()
# Out:
# cool      108
# normal     78
# warm       30
# cold       27
# Name: temp_of_extremities, dtype: int64

# %%
df['peripheral_pulse'].value_counts()
# Out:
# normal       114
# reduced      103
# absent         8
# increased      5
# Name: peripheral_pulse, dtype: int64

# %%
df['mucous_membrane'].value_counts()
# Out:
# normal_pink      79
# pale_pink        57
# pale_cyanotic    41
# bright_pink      30
# bright_red       25
# dark_cyanotic    20
# Name: mucous_membrane, dtype: int64

# %%
df['capillary_refill_time'].value_counts()
# Out:
# less_3_sec    187
# more_3_sec     78
# 3               2
# Name: capillary_refill_time, dtype: int64

# %%
df['pain'].value_counts()
# Out:
# mild_pain       67
# depressed       59
# extreme_pain    42
# severe_pain     38
# alert           38
# Name: pain, dtype: int64

# %%
df['peristalsis'].value_counts()
# Out:
# hypomotile     127
# absent          73
# hypermotile     39
# normal          16
# Name: peristalsis, dtype: int64

# %%
df['abdominal_distention'].value_counts()
# Out:
# none        75
# slight      65
# moderate    65
# severe      38
# Name: abdominal_distention, dtype: int64

# %%
#fillna 
df['temp_of_extremities'] = df['temp_of_extremities'].fillna('cold')
df['peripheral_pulse'] = df['peripheral_pulse'].fillna('increased')
df['mucous_membrane'] = df['mucous_membrane'].fillna('dark_cyanotic')
df['capillary_refill_time'] = df['capillary_refill_time'].fillna('3')
df['pain'] = df['pain'].fillna('alert')
df['peristalsis'] = df['peristalsis'].fillna('normal')
df['abdominal_distention'] = df['abdominal_distention'].fillna('severe')

# %%
df.isnull().sum()
# Out:
# surgery                  0
# age                      0
# rectal_temp              0
# pulse                    0
# respiratory_rate         0
# temp_of_extremities      0
# peripheral_pulse         0
# mucous_membrane          0
# capillary_refill_time    0
# pain                     0
# peristalsis              0
# abdominal_distention     0
# packed_cell_volume       0
# total_protein            0
# outcome                  0
# surgical_lesion          0
# lesion_1                 0
# lesion_2                 0
# lesion_3                 0
# cp_data                  0
# dtype: int64

# %%
## traget colums 'Outcome'
df['outcome'].value_counts()
# Out:
# lived         178
# died           77
# euthanized     44
# Name: outcome, dtype: int64

# %%
# Euthanized is also a died state 
df['outcome'].replace(to_replace='euthanized',value='died',inplace=True)

# %%
#Now it correct
df['outcome'].value_counts()
# Out:
# lived    178
# died     121
# Name: outcome, dtype: int64

# %%
#--
df.head(10)
# Out:
#   surgery    age  rectal_temp  pulse  respiratory_rate temp_of_extremities  \
# 0      no  adult    38.500000   66.0         28.000000                cool
# 1     yes  adult    39.200000   88.0         20.000000                cold
# 2      no  adult    38.300000   40.0         24.000000              normal
# 3     yes  young    39.100000  164.0         84.000000                cold
# 4      no  adult    37.300000  104.0         35.000000                cold
# 5      no  adult    38.168619   72.0         30.460581                warm
# 6     yes  adult    37.900000   48.0         16.000000              normal
# 7     yes  adult    38.168619   60.0         30.460581                cool
# 8      no  adult    38.168619   80.0         36.000000                cool
# 9      no  young    38.300000   90.0         30.460581              normal
#
#   peripheral_pulse mucous_membrane capillary_refill_time          pain  \
# 0          reduced   dark_cyanotic            more_3_sec  extreme_pain
# 1        increased   pale_cyanotic            less_3_sec     mild_pain
# 2           normal       pale_pink            less_3_sec     mild_pain
# 3           normal   dark_cyanotic            more_3_sec     depressed
# 4        increased   dark_cyanotic            more_3_sec         alert
# 5           normal       pale_pink            less_3_sec     depressed
# 6           normal     normal_pink            less_3_sec     mild_pain
# 7        increased   dark_cyanotic            less_3_sec         alert
# 8           absent       pale_pink            less_3_sec   severe_pain
# 9        increased     normal_pink            less_3_sec  extreme_pain
#
#   peristalsis abdominal_distention  packed_cell_volume  total_protein outcome  \
# 0      absent               severe           45.000000       8.400000    died
# 1      absent               slight           50.000000      85.000000    died
# 2  hypomotile                 none           33.000000       6.700000   lived
# 3      absent               severe           48.000000       7.200000    died
# 4      normal               severe           74.000000       7.400000    died
# 5  hypomotile               slight           46.307407      24.274436   lived
# 6  hypomotile             moderate           37.000000       7.000000   lived
# 7      absent               slight           44.000000       8.300000    died
# 8      absent               severe           38.000000       6.200000    died
# 9  hypomotile                 none           40.000000       6.200000   lived
#
#   surgical_lesion  lesion_1  lesion_2  lesion_3 cp_data
# 0              no     11300         0         0      no
# 1              no      2208         0         0      no
# 2              no         0         0         0     yes
# 3             yes      2208         0         0     yes
# 4              no      4300         0         0      no
# 5              no         0         0         0      no
# 6             yes      3124         0         0      no
# 7             yes      2208         0         0      no
# 8             yes      3205         0         0      no
# 9              no         0         0         0     yes

# %% [markdown]
# ## EDA ~Plots

# %%
plt.figure(figsize = (12,6))
sns.catplot(x='surgery',data=df,hue='outcome',col='age',kind='count')
plt.show()

# %%
sns.catplot(x='mucous_membrane',data=df,hue='outcome',kind='count',col='surgery')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='pain',data=df,hue='outcome',kind='count',col='surgery')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='temp_of_extremities',data=df,hue='outcome',kind='count',col='age')

# %%
sns.catplot(x='peripheral_pulse',data=df,hue='outcome',kind='count',col='age')
plt.show()

# %%
sns.catplot(x='peripheral_pulse',data=df,hue='outcome',kind='count',col='surgery')
plt.show()

# %%
sns.catplot(x='abdominal_distention',data=df,hue='age',col='outcome',kind='count')

# %%
plt.figure(figsize=(20,16))
sns.catplot(x="pulse", y="age",hue="outcome", row="pain",data=df,
                orient="h", height=4, aspect=4, palette="Set3",
                kind="violin", dodge=True, cut=0, bw=.2)

# %%
def mix_plot_cat(x,y):
    # 1st plot
    fig, axes = plt.subplots(3, 2, figsize=(25, 20))
    sns.set_style("darkgrid");
    sns.violinplot(ax=axes[0, 0],data=df, x=x, y=y, hue="outcome")
    # 2nd plot
    sns.barplot(ax=axes[0, 1],data=df, x=x, y=y, hue="outcome") 
    # 3rd plot
    sns.boxenplot(ax=axes[1, 0],data=df, x=x, y=y, hue="outcome") 
    # 4th plot
    sns.stripplot(ax=axes[1, 1],data=df, x=x, y=y, hue="outcome") 
    # 5th
    sns.pointplot(ax=axes[2, 0],data=df, x=x, y=y, hue="outcome")  
    # 6th
    sns.boxplot(ax=axes[2, 1],data=df, x=x, y=y, hue="outcome")

# %% [markdown]
# #### Pulse Vs Age

# %%
mix_plot_cat('pulse','age')

# %% [markdown]
# #### Respiratory_rate Vs Age

# %%
mix_plot_cat('respiratory_rate','age')

# %% [markdown]
# #### Total_protein VS Age

# %%
mix_plot_cat('total_protein','age')

# %% [markdown]
# #### Pluse vs Pain

# %%
mix_plot_cat('pulse','pain')

# %%
plt.figure(figsize=(20,16))
sns.catplot(x="respiratory_rate", y="surgery",hue="outcome", row="age",data=df,
                orient="h", height=4, aspect=4, palette="Set3",
                kind="violin", dodge=True, cut=0, bw=.2)

# %%
#Pair plot
sns.pairplot(df,hue='outcome')

# %% [markdown]
# ## Numerical Columns

# %%
num_lst=[]
for col in df.columns:
    if df[col].dtypes != 'object':
        num_lst.append(col)

# %%
num_lst
# Out:
# ['rectal_temp',
#  'pulse',
#  'respiratory_rate',
#  'packed_cell_volume',
#  'total_protein',
#  'lesion_1',
#  'lesion_2',
#  'lesion_3']

# %%
df_num = df[['rectal_temp','pulse','respiratory_rate',
             'packed_cell_volume','total_protein','lesion_1','lesion_2','lesion_3']]

# %%
df_num.head()
# Out:
#    rectal_temp  pulse  respiratory_rate  packed_cell_volume  total_protein  \
# 0         38.5   66.0              28.0                45.0            8.4
# 1         39.2   88.0              20.0                50.0           85.0
# 2         38.3   40.0              24.0                33.0            6.7
# 3         39.1  164.0              84.0                48.0            7.2
# 4         37.3  104.0              35.0                74.0            7.4
#
#    lesion_1  lesion_2  lesion_3
# 0     11300         0         0
# 1      2208         0         0
# 2         0         0         0
# 3      2208         0         0
# 4      4300         0         0

# %%
def mix_plot(feature):
    plt.figure(figsize=(16, 6))
    plt.subplot(1, 3, 1)
    feature.plot(kind = 'hist')
    plt.title(f'{feature.name} histogram plot')
    #mean = feature.describe().mean()
    plt.subplot(1, 3, 2)
    mu, sigma = scipy.stats.norm.fit(feature)
    sns.distplot(feature) 
    #plt.legend({'--': mu, 'sigma': sigma})
    plt.axvline(mu, linestyle = '--', color = 'green', )
    plt.axvline(sigma, linestyle = '--', color = 'red')
    plt.title(f'{feature.name} distribution plot')
    plt.subplot(1, 3, 3)
    sns.boxplot(feature)
    plt.title(f'{feature.name} box plot')
    plt.show()

# %%
for i in df_num.columns:
    mix_plot(df_num[i])

# %%
sns.heatmap(df.corr(),cbar=True,square=True,fmt='.2f',annot=True,annot_kws={'size':10},cmap='Pastel2')
sns.set_style('darkgrid')

# %% [markdown]
# ### Categorical Colums

# %%
cat_lst=[]
for col in df.columns:
    if df[col].dtypes == 'object':
        cat_lst.append(col)
cat_lst.remove('outcome')
cat_lst
# Out:
# ['surgery',
#  'age',
#  'temp_of_extremities',
#  'peripheral_pulse',
#  'mucous_membrane',
#  'capillary_refill_time',
#  'pain',
#  'peristalsis',
#  'abdominal_distention',
#  'surgical_lesion',
#  'cp_data']

# %%
#convert all categorical variables to numeric
df[cat_lst] = df[cat_lst].apply(lambda x: pd.factorize(x)[0])

# %%
df['outcome'].value_counts()
# Out:
# lived    178
# died     121
# Name: outcome, dtype: int64

# %%
# target value
df['outcome'] = df['outcome'].map({'lived':0,'died':1}).astype(int)

# %%
df['outcome'].value_counts()
# Out:
# 0    178
# 1    121
# Name: outcome, dtype: int64

# %%
# Independent variable and dependent variable
#Independent 
X = df.loc[:, df.columns != 'outcome']
#dependent
y = df[['outcome']]

# %%
#split data for training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print("Shape X_train :",X_train.shape)
print("Shape y_train :",y_train.shape)
print("Shape X_test  :",X_test.shape)
print("Shape y_test  :",y_test.shape)
# Out:
# Shape X_train : (200, 19)
# Shape y_train : (200, 1)
# Shape X_test  : (99, 19)
# Shape y_test  : (99, 1)

# %%
from sklearn.preprocessing import StandardScaler
Scaler =StandardScaler()
X =Scaler.fit_transform(X)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
import xgboost 
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold ,StratifiedKFold
from sklearn import metrics
from sklearn.pipeline import Pipeline

# %%
pipe_LR=Pipeline([('scaler1',StandardScaler()),
                 ('LR',LogisticRegression(random_state=2))])
pipe_Ada=Pipeline([('scaler2',StandardScaler()),
                    ('Ada',AdaBoostClassifier(learning_rate=0.1,random_state=2))])
pipe_DT=Pipeline([('scaler3',StandardScaler()),
                  ('DTR',DecisionTreeClassifier())])
pipe_RF=Pipeline([('scaler4',StandardScaler()),
                  ('RFR',RandomForestClassifier())])
pipe_Knn=Pipeline([('scaler5',StandardScaler()),
                   ('Knn',KNeighborsClassifier())])
pipe_Xgb =Pipeline([('scaler5',StandardScaler()),
                   ('Xgboost',XGBClassifier(learning_rate=0.1,random_state=5))])

# %%
pipeline=[pipe_LR,pipe_Ada,pipe_DT,pipe_RF,pipe_Knn,pipe_Xgb]
pipe_dict ={0:'Lr',1:'Ada',2:'DT',3:'RF',4:'Knn',5:'Xgb'}

# %%
pipe_dict={0:'LogisticRegression',1:'AdaBoostClassifier',2:'DecisionTreeClassifier',3:'RandomForestClassifier'
           ,4:'KNeighborsClassifier',5:'XGBClassifier'}

# %%
for pipe in pipeline:
  pipe.fit(X_train,y_train)

# %%
for i,models in enumerate(pipeline):
  print("{} Accuracy : {}".format(pipe_dict[i],models.score(X_test,y_test)))
# Out:
# LogisticRegression Accuracy : 0.7373737373737373
# AdaBoostClassifier Accuracy : 0.7373737373737373
# DecisionTreeClassifier Accuracy : 0.7777777777777778
# RandomForestClassifier Accuracy : 0.797979797979798
# KNeighborsClassifier Accuracy : 0.7878787878787878
# XGBClassifier Accuracy : 0.7575757575757576

# %%
model_knn =KNeighborsClassifier()
model_knn.fit(X_train,y_train)
y_pred =model_knn.predict(X_test)

# %%
print('Accuracy_Score :',metrics.accuracy_score(y_test,y_pred))
print('Classification_report:\n',metrics.classification_report(y_test,y_pred))
print('Confusion_mat:\n',metrics.confusion_matrix(y_test,y_pred))
# Out:
# Accuracy_Score : 0.7777777777777778
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        57
#            1       0.74      0.74      0.74        42
#
#     accuracy                           0.78        99
#    macro avg       0.77      0.77      0.77        99
# weighted avg       0.78      0.78      0.78        99
#
# Confusion_mat:
#  [[46 11]
#  [11 31]]

# %%
error_rate=[]
for i in range(1,30):
  model_knn =KNeighborsClassifier(n_neighbors=i)
  model_knn.fit(X_train,y_train)
  pred_i =model_knn.predict(X_test)
  error_rate.append(np.mean(pred_i) != np.mean(y_test))

# %%
plt.figure(figsize=(10,5))
plt.plot(range(1,30),error_rate,color='blue', linestyle='dashed', marker='o',markerfacecolor='red', markersize=8)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# ## Thank You :)
